# %% [markdown]
# ### 정적 페이지 크롤링하기 - 공공데이터

# %%
from bs4 import BeautifulSoup
import urllib.request as req

# API 요청 후, 응답결과를 xml 파일로 저장
url = "https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
filename = "forecast.xml"
req.urlretrieve(url, filename)

# 저장된 xml 파일을 읽어드려, 데이터 추출
info = {}
xml = open(filename, 'r', encoding="utf-8").read()
soup = BeautifulSoup(xml, 'xml')

# find_all("location") : <location> 태그들을 읽어옴
for location in soup.find_all("location"):
    city = location.find('city').string     # 도시
    min_t = location.find_all('tmn')        # 최저기온
    max_t = location.find_all('tmx')        # 최고기온
    # 최저기온 ~ 최고기온 (10 ~ 25)
    wether = [ a.string+"~"+b.string for a, b in zip(min_t, max_t)]
    # print(f'{city} : {min_t} ~ {max_t}')
    # print(wether)
    
    
    if not (city in info):
        info[city] = []             # {'서울' : {}}
    for data in wether:
        info[city].append(data)     # {'서울' : ['22~29', '22~29', '23~31', '23~31', ...]}
        
print(info)
# Out:
# {'서울': ['22~29', '22~29', '23~31', '23~31', '23~30', '23~30', '23~30', '23~30', '23~29', '23~29', '23~29', '22~28', '22~29'], '인천': ['22~27', '22~27', '22~28', '22~28', '22~27', '22~27', '22~28', '22~28', '23~27', '23~27', '22~26', '22~26', '22~26'], '수원': ['22~28', '22~28', '21~30', '21~30', '22~29', '22~29', '22~29', '22~29', '22~29', '22~29', '22~29', '22~28', '21~29'], '파주': ['21~29', '21~29', '21~30', '21~30', '21~29', '21~29', '21~30', '21~30', '22~29', '22~29', '22~28', '21~29', '21~28'], '이천': ['22~29', '22~29', '21~31', '21~31', '21~30', '21~30', '22~30', '22~30', '22~29', '22~29', '22~29', '21~30', '21~29'], '평택': ['22~30', '22~30', '22~31', '22~31', '23~31', '23~31', '23~30', '23~30', '23~30', '23~30', '23~29', '22~30', '22~30'], '춘천': ['22~30', '22~30', '21~31', '21~31', '21~30', '21~30', '22~30', '22~30', '22~29', '22~29', '22~28', '21~29', '21~29'], '원주': ['22~29', '22~29', '22~31', '22~31', '22~30', '22~30', '23~30', '23~30', '23~30', '23~30', '22~29', '22~30', '22~30'], '강릉': ['24~30', '24~30', '22~28', '22~28', '21~29', '21~29', '21~27', '21~27', '21~27', '21~27', '22~28', '22~28', '22~27'], '대전': ['23~29', '23~29', '22~31', '22~31', '23~31', '23~31', '23~31', '23~31', '23~30', '23~30', '23~29', '23~30', '22~30'], '세종': ['23~29', '23~29', '20~29', '20~29', '22~31', '22~31', '23~31', '23~31', '23~29', '23~29', '24~27', '22~32', '21~30'], '홍성': ['23~28', '23~28', '22~31', '22~31', '23~31', '23~31', '23~30', '23~30', '23~29', '23~29', '23~28', '22~31', '22~28'], '청주': ['23~30', '23~30', '23~31', '23~31', '23~32', '23~32', '24~32', '24~32', '24~31', '24~31', '24~30', '23~30', '23~30'], '충주': ['22~30', '22~30', '21~31', '21~31', '21~31', '21~31', '22~31', '22~31', '22~30', '22~30', '22~29', '21~30', '21~30'], '영동': ['22~30', '22~30', '20~30', '20~30', '21~31', '21~31', '21~31', '21~31', '22~30', '22~30', '22~30', '21~30', '21~31'], '광주': ['23~29', '23~29', '23~31', '23~31', '23~31', '23~31', '24~31', '24~31', '24~30', '24~30', '24~29', '23~31', '23~30'], '목포': ['23~27', '23~27', '23~29', '23~29', '23~29', '23~29', '23~29', '23~29', '23~28', '23~28', '23~27', '23~28', '22~28'], '여수': ['23~26', '23~26', '23~27', '23~27', '23~26', '23~26', '23~28', '23~28', '23~27', '23~27', '23~27', '22~27', '23~28'], '순천': ['24~28', '24~28', '23~31', '23~31', '23~29', '23~29', '24~30', '24~30', '23~28', '23~28', '23~29', '22~30', '23~30'], '광양': ['23~28', '23~28', '23~30', '23~30', '22~30', '22~30', '23~29', '23~29', '23~29', '23~29', '23~29', '23~30', '22~29'], '나주': ['23~28', '23~28', '23~31', '23~31', '22~30', '22~30', '23~30', '23~30', '23~29', '23~29', '23~29', '22~30', '23~31'], '전주': ['24~29', '24~29', '23~31', '23~31', '23~32', '23~32', '24~32', '24~32', '24~31', '24~31', '24~30', '23~31', '23~31'], '군산': ['23~27', '23~27', '22~30', '22~30', '22~30', '22~30', '23~29', '23~29', '23~29', '23~29', '23~28', '22~29', '22~29'], '정읍': ['23~29', '23~29', '22~31', '22~31', '23~32', '23~32', '23~32', '23~32', '23~31', '23~31', '24~30', '23~30', '22~31'], '남원': ['23~29', '23~29', '22~32', '22~32', '22~31', '22~31', '23~31', '23~31', '23~30', '23~30', '23~30', '22~31', '22~30'], '고창': ['23~28', '23~28', '23~30', '23~30', '23~30', '23~30', '23~30', '23~30', '23~29', '23~29', '24~29', '22~29', '22~28'], '무주': ['23~29', '23~29', '20~31', '20~31', '21~31', '21~31', '22~31', '22~31', '22~30', '22~30', '22~30', '21~31', '21~30'], '부산': ['23~27', '23~27', '22~27', '22~27', '22~28', '22~28', '23~28', '23~28', '23~27', '23~27', '23~27', '22~27', '22~28'], '울산': ['24~28', '24~28', '22~27', '22~27', '21~29', '21~29', '22~29', '22~29', '22~28', '22~28', '23~28', '22~29', '22~29'], '창원': ['23~28', '23~28', '22~29', '22~29', '22~29', '22~29', '22~29', '22~29', '22~28', '22~28', '23~28', '22~29', '22~29'], '진주': ['23~29', '23~29', '22~30', '22~30', '22~30', '22~30', '22~29', '22~29', '23~29', '23~29', '23~29', '22~30', '21~29'], '거창': ['23~29', '23~29', '21~30', '21~30', '21~31', '21~31', '21~30', '21~30', '22~29', '22~29', '21~29', '20~30', '20~29'], ...

# %%
from bs4 import BeautifulSoup
import urllib.request as req

# API 요청 후, 응답결과를 xml 파일로 저장
url = "https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
filename = "forecast.xml"
req.urlretrieve(url, filename)

# 저장된 xml 파일을 읽어드려, 데이터 추출
info = {}
xml = open(filename, 'r', encoding="utf-8").read()
soup = BeautifulSoup(xml, 'xml')

# find_all("location") : <location> 태그들을 읽어옴
for location in soup.find_all("location"):
    city = location.find('city').string     # 도시
    min_t = location.find_all('tmn')        # 최저기온
    max_t = location.find_all('tmx')        # 최고기온
    date = location.find_all('tmEf')        # 날짜시간
    wether = []
    for i in range( len(min_t) ):       # 13
        item = {}
        item['min_t'] = min_t[i]    
        item['max_t'] = max_t[i]    
        item['date'] = date[i]
        wether.append(item)
        
    if not (city in info):
        info[city] = []             # {'서울' : {}}
    for data in wether:
        info[city].append(data)     # {'서울' : ['22~29', '22~29', '23~31', '23~31', ...]}
        
print(info)
# Out:
# {'서울': [{'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-06-30 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-06-30 12:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>31</tmx>, 'date': <tmEf>2023-07-01 00:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>31</tmx>, 'date': <tmEf>2023-07-01 12:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>30</tmx>, 'date': <tmEf>2023-07-02 00:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>30</tmx>, 'date': <tmEf>2023-07-02 12:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>30</tmx>, 'date': <tmEf>2023-07-03 00:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>30</tmx>, 'date': <tmEf>2023-07-03 12:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-04 00:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-04 12:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-05 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>28</tmx>, 'date': <tmEf>2023-07-06 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-07 00:00</tmEf>}], '인천': [{'min_t': <tmn>22</tmn>, 'max_t': <tmx>27</tmx>, 'date': <tmEf>2023-06-30 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>27</tmx>, 'date': <tmEf>2023-06-30 12:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>28</tmx>, 'date': <tmEf>2023-07-01 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>28</tmx>, 'date': <tmEf>2023-07-01 12:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>27</tmx>, 'date': <tmEf>2023-07-02 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>27</tmx>, 'date': <tmEf>2023-07-02 12:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>28</tmx>, 'date': <tmEf>2023-07-03 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>28</tmx>, 'date': <tmEf>2023-07-03 12:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>27</tmx>, 'date': <tmEf>2023-07-04 00:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>27</tmx>, 'date': <tmEf>2023-07-04 12:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>26</tmx>, 'date': <tmEf>2023-07-05 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>26</tmx>, 'date': <tmEf>2023-07-06 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>26</tmx>, 'date': <tmEf>2023-07-07 00:00</tmEf>}], '수원': [{'min_t': <tmn>22</tmn>, 'max_t': <tmx>28</tmx>, 'date': <tmEf>2023-06-30 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>28</tmx>, 'date': <tmEf>2023-06-30 12:00</tmEf>}, {'min_t': <tmn>21</tmn>, 'max_t': <tmx>30</tmx>, 'date': <tmEf>2023-07-01 00:00</tmEf>}, {'min_t': <tmn>21</tmn>, 'max_t': <tmx>30</tmx>, 'date': <tmEf>2023-07-01 12:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-02 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-02 12:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-03 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-03 12:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-04 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-04 12:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-05 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>28</tmx>, 'date': <tmEf>2023-07-06 00:00</tmEf>}, {'min_t': <tmn>21</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-07 00:00</tmEf>}], '파주': [{'min_t': <tmn>21</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-06-30 00:00</tmEf>}, {'min_t': <tmn>21</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-06-30 12:00</tmEf>}, {'min_t': <tmn>21</tmn>, 'max_t': <tmx>30</tmx>, 'date': <tmEf>2023-07-01 00:00</tmEf>}, {'min_t': <tmn>21</tmn>, 'max_t': <tmx>30</tmx>, 'date': <tmEf>2023-07-01 12:00</tmEf>}, {'min_t': <tmn>21</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-02 00:00</tmEf>}, {'min_t': <tmn>21</tmn>, 'max_t': <tmx>29</tmx>, 'da ...

# %% [markdown]
# ### 네이버 검색을 통한 서울, 부산, 제주도 날씨 정보 가져오기

# %%
from bs4 import BeautifulSoup
import urllib.request

# 서울 날씨
print('----------- 서울 날씨')
html_text = urllib.request.urlopen('https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query='+ urllib.parse.quote_plus('서울날씨') )
soup = BeautifulSoup(html_text, 'html.parser')
temp = soup.select('.temperature_text > strong')
cast = soup.select('.weather.before_slash')
print( temp[0].contents[1] + '(' + cast[0].text + ')' ) 

# 부산 날씨
print('----------- 부산 날씨')
html_text = urllib.request.urlopen('https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query='+ urllib.parse.quote_plus('부산날씨') )
soup = BeautifulSoup(html_text, 'html.parser')
temp = soup.select('.temperature_text > strong')
cast = soup.select('.weather.before_slash')
print( temp[0].contents[1] + '(' + cast[0].text + ')' ) 

# 제주 날씨
print('----------- 제주 날씨')
html_text = urllib.request.urlopen('https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query='+ urllib.parse.quote_plus('제주날씨') )
soup = BeautifulSoup(html_text, 'html.parser')
temp = soup.select('.temperature_text > strong')
cast = soup.select('.weather.before_slash')
print( temp[0].contents[1] + '(' + cast[0].text + ')' )
# Out:
# ----------- 서울 날씨
# 25.2(흐림)
# ----------- 부산 날씨
# 24.0(흐림)
# ----------- 제주 날씨
# 25.8(비)

# %% [markdown]
# ### 버스 이용정보 조회하기 - 서울시 버스 정보

# %%
from bs4 import BeautifulSoup
import urllib.request as req


# 버스번호로 busRouteId 가져오기
busNum = '741'
key = 'pN%2BytzVI7JbBL3vNuwCa5vj5cTnHnks3DdmpnfYDwND9QIYxkUvQF0jBy%2Ffss4rDRpvYiH2eZQXNzfRlClf88A%3D%3D'
url1 = 'http://ws.bus.go.kr/api/rest/busRouteInfo/getBusRouteList?serviceKey='+key+'&strSrch='+busNum
res = req.urlopen(url1)

result = res.read().decode('utf-8')

soup = BeautifulSoup( result, 'xml')

busRouteId = None
for itemList in soup.find_all('itemList'):
    busRouteId = itemList.find('busRouteId').string
    busRouteNm = itemList.find('busRouteNm').string
    if busRouteNm == busNum :
        break
    
print(f' busRouteId : {busRouteId}')
print(f' busRouteNm : {busRouteNm}')


# 노선별 경유 정류소 
url2 = 'http://ws.bus.go.kr/api/rest/busRouteInfo/getStaionByRoute?serviceKey='+key+'&busRouteId='+busRouteId
res = req.urlopen(url2)
result = res.read()
print(result)
soup = BeautifulSoup( result, 'xml' )

# print( soup.prettify() )

busPos = []
for itemList in soup.find_all('itemList'):
    stationNm = itemList.find('stationNm').string
    gpsY = itemList.find('gpsY').string
    gpsX = itemList.find('gpsX').string
    beginTm = itemList.find('beginTm').string
    lastTm = itemList.find('lastTm').string
    
    busPos.append( (stationNm, gpsY, gpsX, beginTm, lastTm) )
    
print( busNum + '번 버스 정류소 위치')
for stationNm, lat, lng, beginTm, lastTm in busPos:
    print( stationNm, ':', lat +','+ lng + ' (' + beginTm + '~' + lastTm +')' )       # 위도, 경도
# Out:
#  busRouteId : 123000010
#  busRouteNm : 741
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><ServiceResult><comMsgHeader/><msgHeader><headerCd>0</headerCd><headerMsg>\xec\xa0\x95\xec\x83\x81\xec\xa0\x81\xec\x9c\xbc\xeb\xa1\x9c \xec\xb2\x98\xeb\xa6\xac\xeb\x90\x98\xec\x97\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4.</headerMsg><itemCount>0</itemCount></msgHeader><msgBody><itemList><arsId>12469</arsId><beginTm>:</beginTm><busRouteAbrv>741</busRouteAbrv><busRouteId>123000010</busRouteId><busRouteNm>741</busRouteNm><direction>\xec\x84\xb8\xea\xb3\xa1\xeb\x8f\x99\xec\x82\xac\xea\xb1\xb0\xeb\xa6\xac</direction><gpsX>126.9079256882</gpsX><gpsY>37.6467463641</gpsY><lastTm>:</lastTm><posX>191875.29101219564</posX><posY>460799.4598604017</posY><routeType>3</routeType><sectSpd>0</sectSpd><section>0</section><seq>1</seq><station>111001112</station><stationNm>\xec\xa7\x84\xea\xb4\x80\xea\xb3\xb5\xec\x98\x81\xec\xb0\xa8\xea\xb3\xa0\xec\xa7\x80</stationNm><stationNo>12469</stationNo><transYn>N</transYn><fullSectDist>0</fullSectDist><trnstnid>122000699</trnstnid></itemList><itemList><arsId>35160</arsId><beginTm>:</beginTm><busRouteAbrv>741</busRouteAbrv><busRouteId>123000010</busRouteId><busRouteNm>741</busRouteNm><direction>\xec\x84\xb8\xea\xb3\xa1\xeb\x8f\x99\xec\x82\xac\xea\xb1\xb0\xeb\xa6\xac</direction><gpsX>126.9056673441</gpsX><gpsY>37.6468589257</gpsY><lastTm>:</lastTm><posX>191676.0254865143</posX><posY>460812.14971557073</posY><routeType>3</routeType><sectSpd>16</sectSpd><section>111601165</section><seq>2</seq><station>218000221</station><stationNm>\xeb\x8f\x99\xec\x82\xb0\xeb\x8f\x99\xeb\x8a\xa5\xeb\xaa\xa8\xed\x89\x81\xec\x9d\xb4.\xed\x95\x9c\xea\xb5\xad\xec\xa7\x80\xec\x97\xad\xeb\x82\x9c\xeb\xb0\xa9\xea\xb3\xb5 </stationNm><stationNo>35160</stationNo><transYn>N</transYn><fullSectDist>637</fullSectDist><trnstnid>122000699</trnstnid></itemList><itemList><arsId>12010</arsId><beginTm>04:00</beginTm><busRouteAbrv>741</busRouteAbrv><busRouteId>123000010</busRouteId><busRouteNm>741</busRouteNm><direction>\xec\x84\xb8\xea\xb3\xa1\xeb\x8f\x99\xec\x82\xac\xea\xb1\xb0\xeb\xa6\xac</direction><gpsX>126.91373</gpsX><gpsY>37.643407</gpsY><lastTm>22:50</lastTm><posX>192387.1272902265</posX><posY>460428.3773045731</posY><routeType>3</routeType><sectSpd>52</sectSpd><section>111602007</section><seq>3</seq><station>111000010</station><stationNm>\xec\x9d\x80\xed\x8f\x89\xeb\x89\xb4\xed\x83\x80\xec\x9a\xb410\xeb\x8b\xa8\xec\xa7\x80</stationNm><stationNo>12010</stationNo><transYn>N</transYn><fullSectDist>816</fullSectDist><trnstnid>122000699</trnstnid></itemList><itemList><arsId>12012</arsId><beginTm>04:01</beginTm><busRouteAbrv>741</busRouteAbrv><busRouteId>123000010</busRouteId><busRouteNm>741</busRouteNm><direction>\xec\x84\xb8\xea\xb3\xa1\xeb\x8f\x99\xec\x82\xac\xea\xb1\xb0\xeb\xa6\xac</direction><gpsX>126.916837</gpsX><gpsY>37.637116</gpsY><lastTm>22:51</lastTm><posX>192660.6848378089</posX><posY>459729.96820958285</posY><routeType>3</routeType><sectSpd>46</sectSpd><section>111603572</section><seq>4</seq><station>111000012</station><stationNm>\xea\xb5\xac\xed\x8c\x8c\xeb\xb0\x9c\xec\x97\xad\xec\x9e\x85\xea\xb5\xac</stationNm><stationNo>12012</stationNo><transYn>N</transYn><fullSectDist>796</fullSectDist><trnstnid>122000699</trnstnid></itemList><itemList><arsId>12014</arsId><beginTm>04:03</beginTm><busRouteAbrv>741</busRouteAbrv><busRouteId>123000010</busRouteId><busRouteNm>741</busRouteNm><direction>\xec\x84\xb8\xea\xb3\xa1\xeb\x8f\x99\xec\x82\xac\xea\xb1\xb0\xeb\xa6\xac</direction><gpsX>126.9191891249</gpsX><gpsY>37.6308651522</gpsY><lastTm>22:53</lastTm><posX>192867.6675526896</posX><posY>459036.0820702384</posY><routeType>3</routeType><sectSpd>46</sectSpd><section>111602011</section><seq>5</seq><station>111000014</station><stationNm>\xeb\xb0\x95\xec\x84\x9d\xea\xb3\xa0\xea\xb0\x9c.\xec\x8b\xa0\xeb\x8f\x84\xea\xb3\xa0\xeb\x93\xb1\xed\x95\x99\xea\xb5\x90</stationNm><stationNo>12014</stationNo><transYn>N</transYn><fullSectDist>749</fullSectDist><trnstnid>122000699</trnstnid></itemList ...
# 741번 버스 정류소 위치
# 진관공영차고지 : 37.6467463641,126.9079256882 (:~:)
# 동산동능모퉁이.한국지역난방공  : 37.6468589257,126.9056673441 (:~:)
# 은평뉴타운10단지 : 37.643407,126.91373 (04:00~22:50)
# 구파발역입구 : 37.637116,126.916837 (04:01~22:51)
# 박석고개.신도고등학교 : 37.6308651522,126.9191891249 (04:03~22:53)
# 세명컴퓨터고등학교 : 37.6252825924,126.9199961366 (04:05~22:54)
# 연신내역.연서시장 : 37.6193225551,126.9209337015 (04:06~22:55)
# 동명여고.천주교불광동성당 : 37.6162184832,126.9239252428 (04:10~22:57)
# 불광역3.6호선 : 37.6124473901,126.9281552459 (04:11~22:59)
# 불광역3호선.서울혁신파크 : 37.6092474762,126.9309073069 (04:12~23:00)
# 한전서대문은평.북한산푸르지오 : 37.6061799712,126.9336861972 (04:14~23:02)
# 녹번역 : 37.6024349118,126.9350485981 (04:15~23:03)
# 산골고개 : 37.5953018189,126.9399957025 (04:16~23:05)
# 홍제역.서대문세무서 : 37.5884908289,126.944365257 (04:18~23:08)
# 홍제삼거리.인왕산한신휴플러스 : 37.585207045,126.9478427379 (04:21~23:11)
# 무악재역 : 37.5831543142,126.9498097936 (04:23~23:13)
# 안산초등학교 : 37.580686,126.951572 (04:24~23:13)
# 독립문역.한성과학고 : 37.5746889121,126.9575774512 (04:25~23:14)
# 영천시장 : 37.5699391328,126.9625329584 (04:27~23:16)
# 서대문역사거리.농협중앙회 : 37.5669222408,126.9678855112 (04:29~23:18)
# 서울역사박물관.경희궁앞 : 37.569135,126.97038 (04:31~23:21)
# 광화문 : 37.570142,126.976357 (04:33~23:22)
# 종로1가 : 37.5701482455,126.9810660928 (04:34~23:23)
# 종로2가 : 37.57017,126.984991 (04:36~23:26)
# 종로2가.삼일교 : 37.5685792736,126.9876130976 (04:37~23:28)
# 남대문세무서.서울백병원 : 37.5649848069,126.9875299251 (04:39~23:31)
# 남산1호터널 : 37.5574051765,126.9921666231 (04:41~23:34)
# 순천향대학병원.한남오거리 : 37.5354906847,127.0057290409 (04:44~23:38)
# 신사역.푸른저축은행 : 37.5141369914,127.0200636589 (04:48~23:40)
# 논현역 : 37.5072264964,127.0230319441 (04:52~23:45)
# 지하철2호선강남역 : 37.501817,127.025438 (04:54~23:50)
# 신분당선강남역 : 37.4960417459,127.0284005454 (04:56~23:53)
# 래미안아파트.파이낸셜뉴스 : 37.491895,127.030405 (04:58~00:03)
# 뱅뱅사거리 : 37.487667,127.032432 (05:01~00:07)
# 양재역.서초문화예술회관 : 37.48261,127.035902 (05:03~00:08)
# 교육개발원입구 : 37.47859,127.038482 (05:07~00:12)
# 매헌시민의숲 : 37.473135,127.038353 (05:09~00:14)
# AT센터.양재꽃시장 : 37.468707,127.039655 (05:12~00:16)
# 하나로마트.코트라 : 37.4638411943,127.0444478156 (05:13~00:17)
# 염곡마을.서초50플러스센터 : 37.461686,127.04892 (05:15~00:22)
# 탑성마을 : 37.4583465343,127.0564153626 (05:17~00:24)
# 서초포레스타입구 : 37.4569320285,127.0598052456 (05:18~00:26)
# 안골마을 : 37.455227,127.063892 (05:19~00:26)
# 서울특별시어린이병원.강동송파과학화예비군훈련장 : 37.4566030458,127.0702950537 (05:20~00:27)
# 헌인릉.강남서초과학화예비군훈련장 : 37.459599266,127.0795771893 (05:21~00:29)
# 헌인농장 : 37.4614213099,127.0847576347 (05:23~00:30)
# 헌인마을.서울농업기술센터 : 37.4636402535,127.0914525016 (05:24~00:31)
# 세곡푸르지오 : 37.465062,127.096478 (05:25~00:32)
# 강남신동아파밀리에1단지 : 37.4651420524,127.1002962266 (05:25~00:33)
# 은곡마을.강남신동아파밀리에 : 37.465026,127.102457 (05:26~00:33)
# 대왕초등학교 : 37.465113844,127.106685919 (05:26~00:34)
# 은곡마을.LH이편한세상 : 37.4655279204,127.1026344423 (05:28~00:36)
# 은곡마을진입로 : 37.465765644,127.0985783615 (05:38~00:43)
# 세곡푸르지오 : 37.4650999852,127.0949599244 (05:39~00:44)
# 헌인마을.서울농업기술센터 : 37.463226455,127.0893448195 (05:41~00:44)
# 헌인릉.강남서초과학화예비군훈련장 : 37.4611155017,127.0826829531 (05:42~00:45)
# 서울특별시어린이병원.강동송파과학화예비군훈련장 : 37.4575866482,127.0718263325 (05:43~00:46)
# 안골마을 : 37.4562835966,127.0623888747 (05:45~00:48)
# 서초포레스타입구 : 37.457707,127.059144 (05:46~00:50)
# 탑성마을 : 37.4595286806,127.0547296866 (05:47~00:50)
# 염곡마을.서초50플러스센터 : 37.46200197,127.0491561488 (05:48~00:51)
# 코트라 : 37.4646377256,127.0445760316 (05:49~00:52)
# 양재2동주민센터.양재꽃시장 : 37.4695857229,127.0394643327 (05:50~00:54)
# 언남고교 : 37.4732795382,127.0389281035 (05:54~00:50)
# 교육개발원입구 : 37.477818,127.038758 (05:55~00:58)
# 양재역.서초문화예술회관 : 37.481927,127.036827 (05:56~00:59)
# 뱅뱅사거리 : 37.486653,127.033097 (05:58~01:00)
# 래미안아파트.파이낸셜뉴스 : 37.491087,127.030987 (06:01~01:02)
# 신분당선강남역 : 37.494993,127.029112 (06:04~01:04)
# 지하철2호선강남역 : 37.500785,127.02637 (06:06~01:06)
# 논현역 : 37.506367,127.023728 (06:08~01:09)
# 신사역 : 37.512972,127.020607 (06:11~01:12)
# 한남대교전망카페 : 37.5244775345,127.0160048712 (06:15~01:15)
# 한남5거리 : 37.5328656324,127.0083381045 (06:19~01:17)
# 순천향대학병원 : 37.5364422432,127.0057302453 (06:21~01:19)
# 서울백병원.국가인권위.안중근활동터 : 37.5643504711,126.9878515151 (06:24~01:20)
# 종로2가사거리 : 37.569808,126.987752 (06:29~01:26)
# 종로2가 : 37.570238,126.986536 (06:31~01:28)
# 종로1가 : 37.570271,126.98163 (06:32~01:28)
# 광화문 : 37.570216807,126.978085488 (06:34~01:29)
# 서울역사박물관.경교장.강북삼성병원 : 37.570023,126.971248 (06:35~01:31)
# 서대문역사거리.적십자병원 : 37.5671081521,126.9675878497 (06:37~01:33)
# 영천시장 : 37.5696103835,126.963006327 (06:38~01:34)
# 독립문역.한성과학고 : 37.575642,126.95656 (06:40~01:36)
# 무악재역 : 37.5818652109,126.9506553191 (06:41~01:38)
# 인왕산.홍제원아파트 : 37.5843965104,126.9488623648 (06:44~01:40)
# 홍제역.서대문세무서 : 37.5878433932,126.9453225684 (06:44~01:40)
# 산골고개 : 37.5946921221,126.9406677327 (06:46~01:41)
# 녹번역 : 37.6018619707,126.935322042 (06:49~01:43)
# 한전서대문은평.북한산푸르지오 : 37.605373898,126.934400456 (06:51~01:45)
# 불광역3호선.서울혁신파크 : 37.6084378901,126.9317496183 (06:52~01:47)
# 불광역3.6호선 : 37.6119112959,126.9287979055 (06:54~01:48)
# 동명여고.천주교불광동성당 : 37.6154822189,126.9252128099 (06:56~01:49)
# 연신내역.연서시장 : 37.6183598996,126.9218398322 (06:57~01:51)
# 세명컴퓨터고등학교 : 37.6242147932,126.9199734902 (06:59~01:52)
# 박석고개.신도고등학교 : 37.629919,126.919374 (07:01~01:54)
# 구파발역입구 : 37.636164,126.917023 (07:03~01:56)
# 은평뉴타운10단지 : 37.642948,126.915165 (07:06~01:59)
# 진관공영차고지 : 37.6466084782,126.9081867563 (07:09~02:04)

# %% [markdown]
# ### 네이버 블로그 검색

# %%
import requests
import urllib

# 네이버 어플리케이션 등록 - client_id, client_secret
client_id = '4ULRJGNqY2UibRLiENPW'
client_secret = 'c3V0FkJr9o'

query = '영등포 맛집'
query = urllib.parse.quote_plus(query)
display = str(20)

url = 'https://openapi.naver.com/v1/search/blog.json?query=' + query + '&display=' + display

headers = {'X-Naver-Client-Id' : '4ULRJGNqY2UibRLiENPW', 'X-Naver-Client-Secret' : 'c3V0FkJr9o'} 

res = requests.get( url, headers=headers )
status = res.status_code

if( status == 200 ):
    data_result = res.json()
    # print(data_result)
    for count, data in enumerate(data_result['items'], 1):
        print(str(count) + ' : ' + data['title'])
        print('---------------')
        print( data['description'])
        print( '블로그명 : ' + data['bloggername'])
        print( 'url : ' + data['link'])
        
else:
    print('요청 실패 : ' + status)

# %%
import requests
import urllib
import re

# 네이버 어플리케이션 등록 - client_id, client_secret
client_id = '4ULRJGNqY2UibRLiENPW'
client_secret = 'c3V0FkJr9o'

query = '연신내 맛집'
query = urllib.parse.quote_plus(query)
display = str(20)

url = 'https://openapi.naver.com/v1/search/blog.json?query=' + query + '&display=' + display

headers = {'X-Naver-Client-Id' : '4ULRJGNqY2UibRLiENPW', 'X-Naver-Client-Secret' : 'c3V0FkJr9o'} 

res = requests.get( url, headers=headers )
status = res.status_code

if( status == 200 ):
    data_result = res.json()
    # print(data_result)
    for count, data in enumerate(data_result['items'], 1):
        title = re.sub("</?b>", "", data['title'])                  # 제목에서 <b> </b> 제거
        description = re.sub("</?b>", "", data['description'])      # 내용에서 <b> </b> 제거
        print(str(count) + ' : ' + title)
        print('---------------')
        print( description )
        print( '블로그명 : ' + data['bloggername'])
        print( 'url : ' + data['link'])
        
else:
    print('요청 실패 : ' + status)

# %% [markdown]
# ### 네이버 뉴스 기사 검색

# %%
import urllib
import json
import re

# 네이버 어플리케이션 등록 - client_id, client_secret
client_id = '4ULRJGNqY2UibRLiENPW'
client_secret = 'c3V0FkJr9o'

query = '연신내'
query = urllib.parse.quote_plus(query)
display = str(20)

url = 'https://openapi.naver.com/v1/search/news.json?query=' + query + '&display=' + display
# headers = {'X-Naver-Client-Id' : '4ULRJGNqY2UibRLiENPW', 'X-Naver-Client-Secret' : 'c3V0FkJr9o'} 

request = urllib.request.Request(url)
request.add_header('X-Naver-Client-Id', '4ULRJGNqY2UibRLiENPW')
request.add_header('X-Naver-Client-Secret', 'c3V0FkJr9o')

res = urllib.request.urlopen(request)
status = res.getcode()

if( status == 200 ):
    result = res.read()
    result = json.loads(result)
    
    count = 1
    for data in result['items']:
        print( str(count) + ' : ' + data['title'])
        print('=================')
        print(': ' + data['description'])
    # print(result)
    
else:
    print('요청 실패 : ' + status)
